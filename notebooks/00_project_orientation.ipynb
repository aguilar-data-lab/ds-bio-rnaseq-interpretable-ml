# %% [markdown]
# # Project Orientation
#
# This notebook is a lightweight orientation document for the RNA-seq interpretable ML project.
#
# ## Purpose
# - Clarify the biological question
# - Track high-level decisions
# - Prevent loss of context over time
#
# ## Status
# Setup / planning phase
